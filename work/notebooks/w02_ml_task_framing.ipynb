# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Binary Classification (API payload prioritization).

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target Column: target_is_high_value (1 = High engagement payload / High-value lead, 0 = Low value).

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success Metric: Precision ($\ge 85\%$) and F1-Score. High precision ensures we don't waste expensive LLM/Groq API tokens on false positives.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Unit of Analysis: One row = One single API payload or extracted lead event.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Fixed if/else rules break whenever lead quality shifts or API patterns update. Machine Learning can catch complex, non-linear relationships between API latency, response metadata, and text length automatically.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
import pandas as pd
import numpy as np

# Simulating the data slice
np.random.seed(42)
sample_data = {
    'payload_id': [f"evt_{1000 + i}" for i in range(5)],
    'source_channel': ['linkedin_scraper', 'webhook_api', 'form_submit', 'linkedin_scraper', 'webhook_api'],
    'payload_text_length': [450, 120, 850, 50, 920],
    'api_latency_ms': [180, 450, 210, 800, 195],
    'metadata_complete_ratio': [0.95, 0.40, 1.00, 0.20, 0.85]
}

# Creating the unit of analysis dataframe
df = pd.DataFrame(sample_data)

# Sketching the target column using simple proxy logic
df['target_is_high_value'] = ((df['metadata_complete_ratio'] > 0.6) & (df['api_latency_ms'] < 300)).astype(int)

# Display the final output grid inside the notebook
print("--- UNIT OF ANALYSIS DATAFRAME ---")
display(df)
# Out:
# --- UNIT OF ANALYSIS DATAFRAME ---
#   payload_id    source_channel  payload_text_length  api_latency_ms  \
# 0   evt_1000  linkedin_scraper                  450             180
# 1   evt_1001       webhook_api                  120             450
# 2   evt_1002       form_submit                  850             210
# 3   evt_1003  linkedin_scraper                   50             800
# 4   evt_1004       webhook_api                  920             195
#
#    metadata_complete_ratio  target_is_high_value
# 0                     0.95                     1
# 1                     0.40                     0
# 2                     1.00                     1
# 3                     0.20                     0
# 4                     0.85                     1
